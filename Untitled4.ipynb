# %% [markdown]
# <a href="https://colab.research.google.com/github/christianmateus125/ProgramacaoDomJoao/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("comparando números")
#comparar os números


float(input("digitre o primeiro número"))
float(input("digite o segundo número:"))

if número_1 > número_2:



50>10
# Out:
#   File "/tmp/ipython-input-1299346236.py", line 8
#     if número_1>número_2
#                         ^
# SyntaxError: expected ':'
